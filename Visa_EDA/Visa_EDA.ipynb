# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Visa Dataset

# %%
visa = pd.read_csv('Visadataset.csv')

# %%
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Automated EDA using Pandas-Profiling

# %%
from pandas_profiling import ProfileReport

# %%
report = ProfileReport(visa)
report.to_file('Visa_profile.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Automated EDA using DataPrep

# %%
from dataprep.eda import create_report

# %%
auto_eda = create_report(visa)
auto_eda.save('Visa_DataPrep.html')
# Out:
#   0%|                                                                                         | 0/1414 [00:00<…
# C:\Users\vamsh\AppData\Local\Programs\Python\Python310\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# Report has been saved to Visa_DataPrep.html!

# %% [markdown]
# # Automated EDA using SweetViz

# %%
import sweetviz

# %%
visa_report = sweetviz.analyze(visa)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
visa_report.show_html('Visa_sweet_viz.html')
# Out:
# Report Visa_sweet_viz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# Automated EDA using AutoViz
# Out:
# ...
#   Using cached autoviz-0.1.55-py3-none-any.whl (64 kB)
# ...
#   Using cached hvplot-0.8.1-py2.py3-none-any.whl (3.2 MB)
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df = AV.AutoViz('Visadataset.csv')
# Out:
# Shape of your Data Set loaded: (25480, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# <style type="text/css">
# #T_7888a_row0_col0, #T_7888a_row0_col4, #T_7888a_row1_col0, #T_7888a_row1_col4, #T_7888a_row8_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# ...
